# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu21994/pandas/blob/main/PivotTables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    571     71   John  January      Q1
# 1  2023-01-02       B   West    400     90   Mary  January      Q1
# 2  2023-01-03       C  North    357     25    Bob  January      Q1
# 3  2023-01-04       D  South    904     11  Alice  January      Q1
# 4  2023-01-05       A   East    376     51   John  January      Q1
# 5  2023-01-06       B   West    548     62   Mary  January      Q1
# 6  2023-01-07       C  North    905     73    Bob  January      Q1
# 7  2023-01-08       D  South    144     61  Alice  January      Q1
# 8  2023-01-09       A   East    719     17   John  January      Q1
# 9  2023-01-10       B   West    212     51   Mary  January      Q1
# 10 2023-01-11       C  North    880     96    Bob  January      Q1
# 11 2023-01-12       D  South    647     66  Alice  January      Q1
# 12 2023-01-13       A   East    757     37   John  January      Q1
# 13 2023-01-14       B   West    700     70   Mary  January      Q1
# 14 2023-01-15       C  North    190     30    Bob  January      Q1
# 15 2023-01-16       D  South    693     81  Alice  January      Q1
# 16 2023-01-17       A   East    424     44   John  January      Q1
# 17 2023-01-18       B   West    489     71   Mary  January      Q1
# 18 2023-01-19       C  North    385     36    Bob  January      Q1
# 19 2023-01-20       D  South    789     64  Alice  January      Q1

# %%
pd.pivot_table(df, values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     571.0    NaN    NaN    NaN
# North      NaN    NaN  385.0    NaN
# South      NaN    NaN    NaN  693.0
# West       NaN  489.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     569.4    NaN    NaN    NaN  44.0   NaN   NaN   NaN
# North      NaN    NaN  543.4    NaN   NaN   NaN  52.0   NaN
# South      NaN    NaN    NaN  635.4   NaN   NaN   NaN  56.6
# West       NaN  469.8    NaN    NaN   NaN  68.8   NaN   NaN

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
